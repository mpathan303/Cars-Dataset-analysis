# %% [markdown]
# # CARS DATASET (Audi, BMW, Ford, Hyundai, Skoda, VW)

# %% [markdown]
# **Working on Real Project with Python**

# %% [markdown]
# This dataset is the stacked version of 100,000 UK Used Car Data set present in Kaggle. Here I have combined the used car information of 7 brands namely Audi, BMW, Skoda, Ford, Volkswagen, Toyota and Hyundai.
#
#
# This data is available as a CSV file, I am going to analyze this dataset using Pandas Dataframe.

# %%
import pandas as pd

# %%
car=pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\cars_dataset.csv")

# %%
car
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3           A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4           A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431      I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72432      I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %%
car.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %% [markdown]
#  **1. ( For Data Cleaning ) - Finding all Null Values in the dataset. If there is any null value in any column, then i will fill it with the mean of that column.**

# %%
car.shape
# Out:
# (72435, 10)

# %% [markdown]
# Here we have 72435 rows and 10 columns

# %%
car.isnull()
# Out:
#        model   year  price  transmission  mileage  fuelType    tax    mpg  \
# 0      False  False  False         False    False     False  False  False
# 1      False  False  False         False    False     False  False  False
# 2      False  False  False         False    False     False  False  False
# 3      False  False  False         False    False     False  False  False
# 4      False  False  False         False    False     False  False  False
# ...      ...    ...    ...           ...      ...       ...    ...    ...
# 72430  False  False  False         False    False     False  False  False
# 72431  False  False  False         False    False     False  False  False
# 72432  False  False  False         False    False     False  False  False
# 72433  False  False  False         False    False     False  False  False
# 72434  False  False  False         False    False     False  False  False
#
#        engineSize   Make
# 0           False  False
# 1           False  False
# ...

# %%
car.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             3
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
car['tax'].fillna(car['tax'].mean())
# Out:
# 0        150.0
# 1         20.0
# 2         30.0
# 3        145.0
# 4        145.0
#          ...
# 72430      0.0
# 72431     30.0
# 72432     20.0
# 72433    145.0
# 72434    125.0
# Name: tax, Length: 72435, dtype: float64

# %%
car['tax'].fillna(car['tax'].mean(), inplace=True)

# %%
car.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %% [markdown]
# **( Based on Value Counts )- Now I will check what are the different types of Make are there in my dataset. And, what is the count (occurrence) of each make in the data.**

# %%
car.head(2)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
#
#    Make
# 0  audi
# 1  audi

# %%
car['Make'].value_counts()
# Out:
# Ford       17964
# vw         15157
# BMW        10781
# audi       10668
# toyota      6738
# skoda       6267
# Hyundai     4860
# Name: Make, dtype: int64

# %% [markdown]
# **( Filtering ) - Show all the records where it is a petrol car.**

# %%
car.head(2)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
#
#    Make
# 0  audi
# 1  audi

# %%
car['fuelType'].isin(['Petrol'])
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 72430    False
# 72431    False
# 72432     True
# 72433     True
# 72434    False
# Name: fuelType, Length: 72435, dtype: bool

# %%
car[car['fuelType'].isin(['Petrol'])]
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 4           A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# 5           A1  2016  13900    Automatic    32260   Petrol   30.0  58.9
# 8           A3  2015  10200       Manual    46112   Petrol   20.0  60.1
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72425      I10  2018   7200       Manual    17879   Petrol  145.0  60.1
# 72426      I10  2018   7995       Manual     8851   Petrol  145.0  60.1
# 72427      I10  2018   7200       Manual    14788   Petrol  150.0  60.1
# 72432      I10  2017   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2018  13994       Manual    23313   Petrol  145.0  44.8
#
#        engineSize     Make
# 0             1.4     audi
# 2             1.4     audi
# ...

# %% [markdown]
# **( Filtering ) - Show all the records where it is a Diesel car.**

# %%
car[car['fuelType'].isin(['Diesel'])]
# Out:
#            model  year  price transmission  mileage fuelType    tax   mpg  \
# 1             A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 3             A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 6             A6  2016  13250    Automatic    76788   Diesel   30.0  61.4
# 7             A4  2016  11750       Manual    75185   Diesel   20.0  70.6
# 11            A6  2016  16500    Automatic    52198   Diesel  125.0  57.6
# ...          ...   ...    ...          ...      ...      ...    ...   ...
# 72428     Tucson  2016  12495       Manual    35000   Diesel   30.0  61.7
# 72429   Santa Fe  2019  29995    Semi-Auto     1567   Diesel  145.0  39.8
# 72430        I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431        I40  2015   7830       Manual    59508   Diesel   30.0  65.7
# 72434     Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 1             2.0     audi
# ...

# %% [markdown]
# **( Removing unwanted records ) - Remove all the records (rows) where tax is greater than 150.**

# %%
car.head(2)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
#
#    Make
# 0  audi
# 1  audi

# %%
car['tax']>150
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 72430    False
# 72431    False
# 72432    False
# 72433    False
# 72434    False
# Name: tax, Length: 72435, dtype: bool

# %%
car[~(car['tax']>150)]
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2016  12500       Manual    15735   Petrol  150.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3           A4  2016  16800    Automatic    25952   Diesel  145.0  67.3
# 4           A3  2016  17300       Manual     1998   Petrol  145.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    0.0  78.4
# 72431      I40  2016   7830       Manual    59508   Diesel   30.0  65.7
# 72432      I10  2016   6830       Manual    13810   Petrol   20.0  60.1
# 72433   Tucson  2016  13994       Manual    23313   Petrol  145.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  125.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %% [markdown]
#  **( Applying function on a column ) - Increase all the values of 'tax' column by 3.**

# %%
car.head(2)
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2016  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
#
#    Make
# 0  audi
# 1  audi

# %%
car['tax'].apply(lambda x:x+3)
# Out:
# 0        153.0
# 1         23.0
# 2         33.0
# 3        148.0
# 4        148.0
#          ...
# 72430      3.0
# 72431     33.0
# 72432     23.0
# 72433    148.0
# 72434    128.0
# Name: tax, Length: 72435, dtype: float64

# %%
car['tax']=car['tax'].apply(lambda x:x+3)

# %%
car
# Out:
#          model  year  price transmission  mileage fuelType    tax   mpg  \
# 0           A1  2016  12500       Manual    15735   Petrol  153.0  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   23.0  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   33.0  55.4
# 3           A4  2016  16800    Automatic    25952   Diesel  148.0  67.3
# 4           A3  2016  17300       Manual     1998   Petrol  148.0  49.6
# ...        ...   ...    ...          ...      ...      ...    ...   ...
# 72430      I30  2016   8680       Manual    25906   Diesel    3.0  78.4
# 72431      I40  2016   7830       Manual    59508   Diesel   33.0  65.7
# 72432      I10  2016   6830       Manual    13810   Petrol   23.0  60.1
# 72433   Tucson  2016  13994       Manual    23313   Petrol  148.0  44.8
# 72434   Tucson  2016  15999    Automatic    11472   Diesel  128.0  57.6
#
#        engineSize     Make
# 0             1.4     audi
# 1             2.0     audi
# ...

# %% [markdown]
# By Mufaddal Pathan
